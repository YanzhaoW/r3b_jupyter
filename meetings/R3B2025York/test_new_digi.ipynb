# %%
import ROOT
canvas = ROOT.TCanvas("canvas", "canvas", 600, 600)
# Out:
# Welcome to JupyROOT 6.30/08

# %%
# !neuland ana -c "test_config.json"
# Out:
# [INFO] R3BNeulandApp.h:192:ParseApplicationOptionImp(): Reading the configuration from the json file "test_config.json".
# [INFO] R3BNeulandApp.cxx:90:init(): Initializaing application ...
# [INFO] R3BNeulandApp.cxx:189:add_inout_files(): Filesource2: Set to run id 999
# [INFO] R3BFileSource2.cxx:256:AddFileName(): Adding /lustre/r3b/pulrich/Down/sim/4GeV.output.root to file source
#
# [WARN] No time based branch list in input file
# [INFO] R3BNeulandApp.cxx:211:add_inout_pars(): Input first parameter file is "/lustre/r3b/pulrich/Down/sim/4GeV.par.root"
# [INFO] R3BNeulandApp.cxx:232:add_inout_pars(): Ouptut parameter file is "/lustre/r3b/ywang/analysis/jupyter/R3B2025York/test.par.root"
# [INFO] R3BNeulandAnalysisApp.cxx:110:create_neuland_digi_engine_map(): cal_to_hit_par is not used in digitization task!
# [INFO] chain name: evt
# [INFO] FairRootFileSink initialized.
# [INFO]  - r3broot
# [INFO]     - /lustre/r3b/ywang/analysis/jupyter/R3B2025York/test.output.root
# ...

# %%
# !neuland ana --dump-config "test_config.json"
# Out:
# [INFO] R3BNeulandAnalysisApp.cxx:317:dump_json_options(): Configuration of neuland_ana is saved into the file "test_config.json"
