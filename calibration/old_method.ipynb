# %%
import ROOT
import pandas as pd
import numpy as np
import seaborn as sns
from utils import to_data_frame
# Out:
# Welcome to JupyROOT 6.30/02

# %%
filename = "/lustre/r3b/ywang/archive/millepede/cal.par.current.070724.root"
root_file = ROOT.TFile(filename, "read")
data_frame = to_data_frame(root_file, 0)
# Out:
# size of module pars: 1300

# %%
data_frame["t_diff_times_speed"] = data_frame.t_diff * data_frame.effective_speed
data_frame
# Out:
#       bar_id      t_diff  t_diff_error  effective_speed  \
# 0          1   97.659833           0.0        -8.413772
# 1          2   95.397420           0.0        -8.281898
# 2          3   97.112052           0.0        -8.272595
# 3          4   94.615108           0.0        -8.205746
# 4          5  101.550856           0.0        -8.315643
# ...      ...         ...           ...              ...
# 1295    1296   -4.067143           0.0        -8.207075
# 1296    1297   -5.793366           0.0        -8.209397
# 1297    1298   -4.062119           0.0        -8.134259
# 1298    1299   -4.894517           0.0        -8.184698
# 1299    1300   -2.988848           0.0        -8.194268
#
#       effective_speed_error     t_sync  t_sync_error  t_diff_times_speed
# 0                       0.0  -8.854428           0.0         -821.687592
# 1                       0.0  -9.149603           0.0         -790.071750
# 2                       0.0  -9.414849           0.0         -803.368643
# 3                       0.0  -6.980233           0.0         -776.387592
# 4                       0.0 -10.869109           0.0         -844.460664
# ...                     ...        ...           ...                 ...
# 1295                    0.0  45.655461           0.0           33.379344
# 1296                    0.0  46.799311           0.0           47.560041
# 1297                    0.0  47.559894           0.0           33.042323
# 1298                    0.0  46.579991           0.0           40.060145
# 1299                    0.0  46.270858           0.0           24.491419
#
# [1300 rows x 8 columns]

# %%
sns.set_theme(rc={'figure.figsize':(20.7,8.27)})

# %%
ax = sns.lineplot(data = data_frame, x = "bar_id", y = "t_diff" )
ax.set(ylim = (-400, 500), xlim = (0, 1200));

# %%
ax = sns.lineplot(data = data_frame, x = "bar_id", y ="effective_speed" )
ax.set(xlim = (0, 1200));

# %%
ax = sns.lineplot(data = data_frame, x = "bar_id", y ="t_sync" )
ax.set(xlim = (0, 1200));
